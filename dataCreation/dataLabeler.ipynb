# %%
from langchain_community.llms import Ollama
llm = Ollama(model="llama2")

# %%
llm.invoke(prompt_text)
# Out:
# "\nLangsmith is a language model developed by Google that can be used for various natural language processing tasks, including testing. Here are some ways Langsmith can help with testing:\n\n1. Automated Testing: Langsmith can be used to automate testing processes, such as regression testing, where it can generate test cases based on the desired output of a function or method. This can save time and reduce the likelihood of human error.\n2. Test Data Generation: Langsmith can generate test data, such as inputs and outputs, that can be used to test software systems. This can help identify issues early on in the development process and improve overall testing efficiency.\n3. Smoke Testing: Langsmith can be used for smoke testing, which involves running a series of automated tests to verify the basic functionality of a software system. This can help identify major issues early on and ensure that the system is stable enough to move into the development phase.\n4. Test Case Prioritization
# ...

# %%
# Your prompt and words
prompt_text = """Given the following statement from a student, identify the three most fitting words (emotions or disorders) from the provided list. Please choose 2 emotion words and one disorder from that list for the statement. Statement: 'I feel overwhelmed by my upcoming exams and unsure about my future.' List of words: 
Nuanced Emotions:
[Euphoria,
Despondency,
Anxiety,
Melancholy,
Contentment,
Ambivalence,
Nostalgia,
Empathy,
Apathy,
Gratitude,
Serenity,
Envy,
Disgust,
Anticipation,
Remorse,
Indignation,
Exhilaration,
Insecurity,
Curiosity,
Resentment,
Sympathy,
Humiliation,
Optimism,
Pessimism,
Compassion,
Sorrow,
Hopefulness,
Betrayal,
Jealousy,
Pride,
Shame,
Guilt,
Trust,
Suspicion,
Love,
Lust,
Adoration,
Boredom,
Surprise,
Fear,
Anger,
Sadness,
Joy,
Disappointment,
Relief,
Excitement,
Frustration,
Overwhelm,
Loneliness,
Bliss]

Mental Health Conditions (Aligned with DSM-5 or ICD-11 Criteria):
[Major Depressive Disorder,
Generalized Anxiety Disorder,
Obsessive-Compulsive Disorder,
Post-Traumatic Stress Disorder,
Bipolar Disorder,
Schizophrenia,
Anorexia Nervosa,
Bulimia Nervosa,
Binge Eating Disorder,
Attention-Deficit/Hyperactivity Disorder,
Autism Spectrum Disorder,
Social Anxiety Disorder,
Panic Disorder,
Phobias (specify e.g., agoraphobia, claustrophobia),
Dissociative Identity Disorder,
Borderline Personality Disorder,
Narcissistic Personality Disorder,
Avoidant Personality Disorder,
Obsessive-Compulsive Personality Disorder,
Schizoaffective Disorder,
Cyclothymic Disorder,
Dysthymia (Persistent Depressive Disorder),
Adjustment Disorder,
Acute Stress Disorder,
Somatic Symptom Disorder,
Conversion Disorder (Functional Neurological Symptom Disorder),
Insomnia Disorder,
Sleep-Wake Disorder,
Substance Use Disorders (specify e.g., alcohol use disorder, opioid use disorder),
Gambling Disorder,
Internet Gaming Disorder,
Hoarding Disorder,
Trichotillomania (Hair-Pulling Disorder),
Excoriation (Skin-Picking) Disorder,
Body Dysmorphic Disorder,
Paranoid Personality Disorder,
Schizoid Personality Disorder,
Histrionic Personality Disorder,
Dependent Personality Disorder,
Antisocial Personality Disorder,
Intellectual Disability,
Communication Disorders (specify e.g., language disorder, speech sound disorder),
Specific Learning Disorder,
Motor Disorders (specify e.g., Tourettes disorder, developmental coordination disorder),
Delusional Disorder,
Brief Psychotic Disorder,
Shared Psychotic Disorder (Folie à deux),
Reactive Attachment Disorder,
Disinhibited Social Engagement Disorder,
Premenstrual Dysphoric Disorder]
"""
# Out:
# Error while downloading from https://cdn-lfs.huggingface.co/EleutherAI/gpt-neo-2.7B/ac75c6bf3e242ed5df22c1d9eb4a5fa563d201c0beab16711bd3fbb7448b1699?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27model.safetensors%3B+filename%3D%22model.safetensors%22%3B&Expires=1712691044&Policy=_&Signature=x1-RHnjfuXgBTdkZWvKSc9x876IBvfLY86r2uZr6t2kjU7WMljrXqIkyqljLNUuZDc5TaTm8X5MQ9gTJ9zWGzWaMF8zrR69%7EouszagEhAMppbPf6XBlliZAYpvImYRTZB8t65hvX8-SOIX%7E8DLwOhqBZ4UwNJe4s570EWiX5EjRLU78NzDtrsZmiCEOOxK5GvHggEvzoZr-N7uy1ZnUMkpjTCLHe6pfELTMU2JCvfYyBNuj3IAWChiI9E9PJR-4Gptc4-t4%7Ey6Ofkqb%7ER1smghPbieK-yxBZKQPgtv2ckTH95wMHI4xc00iihv7-zdgsB%7E7UFY8hQtJueX6RJvdYLQ__&Key-Pair-Id=
# ...

# %%
# Generate a response
output_sequences = model.generate(
    input_ids=inputs['input_ids'],
    max_length=1024,
    temperature=0.7,
    do_sample=True,
    top_k=50,
    top_p=0.9,
    num_return_sequences=1
)

# Decode the generated text
generated_text = tokenizer.decode(output_sequences[0], skip_special_tokens=True)
print(generated_text)
